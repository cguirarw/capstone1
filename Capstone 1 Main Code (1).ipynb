# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from six.moves import range
import seaborn as sns
import sklearn
import statsmodels.api as sm
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
data = data.drop(columns = "Player")
data = data.drop(columns = "Salary")
data = data.drop(columns = "Pos")
data = data.drop(columns = "Tm")
print(data)
# Out:
#      Age   G    MP   PER    TS%  TRB%  AST%  STL%  BLK%  TOV%  USG%   OWS  \
# 0     25  41   385  14.4  0.500  10.0   6.4   1.2   0.7   3.1  22.3   0.3
# 1     23  64  1086  11.2  0.499   4.5  27.0   1.4   0.8  15.5  19.7   0.4
# 2     21  28   212   9.3  0.546   5.8   8.7   1.2   1.2   9.3  13.8   0.1
# 3     20  50   428  10.5  0.554  10.2   2.6   0.6   0.8   7.3  14.2   0.5
# 4     25  50   520  10.2  0.522   6.7   9.8   1.3   0.2  12.0  17.9   0.1
# 5     22  52   807   7.0  0.511   4.8   9.4   0.7   0.5  11.5  17.5   0.1
# 6     22  28   353  15.4  0.584  12.8   5.9   0.4   3.9  12.2  21.0   0.3
# 7     22  26   328  15.9  0.593  12.3   6.0   0.4   3.6  11.4  20.8   0.3
# 8     26  72  1398   9.1  0.525   4.7  10.1   1.1   0.6  10.2  17.3   0.1
# 9     23  35   692  11.8  0.551   4.7  16.1   1.3   0.7  15.5  22.7   0.1
# 10    24  37   459   9.1  0.554   6.6  10.1   0.8   0.5  13.4  15.5   0.1
# 11    37  76  1566  13.5  0.527   3.4  17.1   1.2   0.4  10.8  24.2   1.1
# 12    33  75  2413  12.7  0.502  10.1   6.4   0.9   1.8   7.4  23.3   1.1
# 13    22  51   728   9.5  0.513  10.9   4.6   2.1   1.3  10.6  14.0   0.1
# 14    35  52  1020  13.1  0.499   4.9  29.0   1.4   0.1  13.4  20.6   0.4
# 15    24  31   414  10.0  0.559   7.2  10.9   0.5   0.5  11.6  16.3   0.2
# 16    32  76  1307  10.1  0.562   4.8   3.5   1.3   0.4   7.3  18.0   0.7
# 17    28  54  1014  10.7  0.519   5.5  23.5   1.7   0.5  16.9  16.9   0.4
# 18    34  58  1483  11.2  0.487   6.7  31.3   1.2   0.2  19.9  16.5   0.3
# 19    24  24   101   8.5  0.520   9.5   2.7   1.5   0.9   7.4  11.9   0.1
# 20    35  43   897   8.9  0.520   5.8  22.4   1.2   0.3  20.9  13.0   0.3
# 21    22  65  1413   9.8  0.530   7.2   7.3   1.0   0.8   8.4  14.4   0.6
# 22    22  33   476  12.0  0.543  19.2   3.8   0.6   1.9  12.0  11.5   0.5
# 23    21  22   173  11.1  0.560   5.8   9.9   1.2   1.5   7.1  14.8   0.2
# 24    23  51   972  13.1  0.479   7.5  22.8   1.8   1.0  12.7  22.5   0.1
# 25    23  69   817  11.1  0.526  10.4   6.0   1.3   0.9  10.3  15.5   0.4
# 26    32  68  1081  11.6  0.539   6.4  16.5   1.5   1.5  13.8  16.5   0.9
# 27    22  24   275  10.0  0.517  11.1   5.9   1.1   0.9  10.2  13.9   0.2
# 28    22  57   584  10.9  0.605  10.0   6.8   1.6   0.4  14.2  15.0   0.4
# 3    0.3   0.7  -4.7  -0.3
# 4    0.4   0.5  -4.7  -0.4
# 5    0.7   0.8  -4.6  -0.5
# 6    0.3   0.6  -4.4  -0.2
# 7    0.3   0.6  -4.2  -0.2
# 8    0.8   0.9  -4.2  -0.8
# 9    0.2   0.4  -4.0  -0.3
# 10   0.2   0.3  -3.9  -0.2
# 11   0.3   1.3  -3.9  -0.8
# 12   2.4   3.5  -3.9  -1.2
# 13   0.7   0.8  -3.8  -0.3
# 14   1.1   1.5  -3.8  -0.5
# 15   0.2   0.4  -3.7  -0.2
# 16   0.9   1.6  -3.7  -0.5
# 17   0.6   1.0  -3.6  -0.4
# 18   0.7   1.0  -3.6  -0.6
# 19   0.1   0.2  -3.5   0.0
# 20   0.5   0.8  -3.4  -0.3
# 21   0.5   1.0  -3.4  -0.5
# 22   0.7   1.2  -3.4  -0.2
# 23   0.1   0.3  -3.3  -0.1
# 24   0.5   0.6  -3.3  -0.3
# 25   0.6   1.1  -3.3  -0.3
# 26   1.0   1.8  -3.3  -0.4
# 27   0.1   0.4  -3.2  -0.1
# 28   0.4   0.8  -3.1  -0.2
# 29   0.5   0.9  -3.1  -0.1
# ..   ...   ...   ...   ...
# 328  3.4   6.2   3.5   3.0
# 329  2.2   5.7   3.6   1.9
# 330  3.0   7.9   3.6   3.3
# 331  1.2   4.3   3.7   2.3
# 332  1.5   3.7   3.7   1.3
# 333  1.9   4.2   4.0   2.0
# 334  3.7   5.9   4.0   2.9
# 335  3.8   7.6   4.1   3.4
# 336  3.6   7.6   4.2   2.7
# 337  1.4   3.0   4.4   1.3
# 338  4.7   8.7   4.4   4.2
# 339  3.8   8.0   4.7   4.2
# 340  1.6   8.4   4.9   3.6
# 341  3.1  13.0   5.3   5.1
# 342  4.5  13.0   5.3   4.7
# 343  0.9   1.6   5.5   0.8
# 344  5.6  10.1   5.5   4.8
# 345  1.7   3.0   5.6   1.5
# 346  3.2   4.7   5.6   3.3
# 347  2.9   9.7   5.8   4.7
# 348  2.9  10.1   5.9   4.4
# 349  3.5  12.1   5.9   5.4
# 350  2.7   9.0   6.4   4.1
# 351  2.6  12.1   6.8   5.7
# 352  2.6   9.9   6.9   5.1
# 353  2.6   9.6   7.0   4.0
# 354  4.3   9.8   8.2   7.2
# 355  1.9   9.2   8.6   4.4
# 356  3.0  13.4   9.7   8.6
# 357  3.6  15.0  11.1   8.1
#
# [358 rows x 16 columns]

# %%
import statsmodels.api as sm

# %%
X = data['VORP']
X2 = data['BPM']
X4 = data['PER']
y = data['WS']
TRB = data['TRB%']
AST = data['AST%']
STL = data['STL%']
BLK = data['BLK%']
TOV = data['TOV%']
USG = data['USG%']           

#Harsh Code: print the variables X, y
print (X)
print (y)
# Out:
# 0     -0.4
# 1     -0.9
# 2     -0.1
# 3     -0.3
# 4     -0.4
# 5     -0.5
# 6     -0.2
# 7     -0.2
# 8     -0.8
# 9     -0.3
# 10    -0.2
# 11    -0.8
# 12    -1.2
# 13    -0.3
# 14    -0.5
# 15    -0.2
# 16    -0.5
# 17    -0.4
# 18    -0.6
# 19     0.0
# 20    -0.3
# 21    -0.5
# 22    -0.2
# 23    -0.1
# 24    -0.3
# 25    -0.3
# 26    -0.4
# 27    -0.1
# 28    -0.2
# 29    -0.1
#       ...
# 328    3.0
# 329    1.9
# 330    3.3
# 331    2.3
# 332    1.3
# 333    2.0
# 334    2.9
# 335    3.4
# 336    2.7
# 337    1.3
# 338    4.2
# 339    4.2
# 340    3.6
# 341    5.1
# 342    4.7
# 343    0.8
# 344    4.8
# 345    1.5
# 346    3.3
# 347    4.7
# 348    4.4
# 349    5.4
# 350    4.1
# 351    5.7
# 352    5.1
# 353    4.0
# 354    7.2
# 355    4.4
# 356    8.6
# 357    8.1
# Name: VORP, Length: 358, dtype: float64
# 0       0.5
# 1       0.8
# 2       0.2
# 3       0.7
# 4       0.5
# 5       0.8
# 6       0.6
# 7       0.6
# 8       0.9
# 9       0.4
# 10      0.3
# 11      1.3
# 12      3.5
# 13      0.8
# 14      1.5
# 15      0.4
# 16      1.6
# 17      1.0
# 18      1.0
# 19      0.2
# 20      0.8
# 21      1.0
# 22      1.2
# 23      0.3
# 24      0.6
# 25      1.1
# 26      1.8
# 27      0.4
# 28      0.8
# 29      0.9
#        ...
# 328     6.2
# 329     5.7
# 330     7.9
# 331     4.3
# 332     3.7
# 333     4.2
# 334     5.9
# 335     7.6
# 336     7.6
# 337     3.0
# 338     8.7
# 339     8.0
# 340     8.4
# 341    13.0
# 342    13.0
# 343     1.6
# 344    10.1
# 345     3.0
# 346     4.7
# 347     9.7
# 348    10.1
# 349    12.1
# 350     9.0
# 351    12.1
# 352     9.9
# 353     9.6
# 354     9.8
# 355     9.2
# 356    13.4
# 357    15.0
# Name: WS, Length: 358, dtype: float64

# %%
model = sm.OLS(X, y).fit()

# %%
predictions = model.predict(y)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   VORP   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     1574.
# Date:                Sun, 09 Dec 2018   Prob (F-statistic):          6.54e-133
# Time:                        11:19:50   Log-Likelihood:                -373.94
# No. Observations:                 358   AIC:                             749.9
# Df Residuals:                     357   BIC:                             753.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# WS             0.3398      0.009     39.671      0.000       0.323       0.357
# ==============================================================================
# Omnibus:                      217.643   Durbin-Watson:                   0.603
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2401.967
# Skew:                           2.365   Prob(JB):                         0.00
# Kurtosis:                      14.775   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn import linear_model

# %%
#Harsh Code: Basically the numpy does not realize the shape of the array when there is only one column. so we need to reshape
#it using reshape (-1, 1). Here -1 allows the numpy to infer the size of array. If you had multiple X column this should not
#happen

print(y.shape)
y1 = y.values.reshape(-1, 1)
print(y1.shape)
print(X.shape)
X1 = X.values.reshape(-1, 1)
print(X1.shape)
X3 = X2.values.reshape(-1, 1)
X5 = X4.values.reshape(-1, 1)
# Out:
# (358,)
# (358, 1)
# (358,)
# (358, 1)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X1,y1)
print(model)
lm1 = linear_model.LinearRegression()
model1 = lm1.fit(X3,y1)
lm2 = linear_model.LinearRegression()
model2 = lm2.fit(X5,y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#Harsh Code
print(model.score(X1, y1))
print(model.coef_)
print(model.intercept_)
# Out:
# 0.8296579197071691
# [[1.75877355]]
# [1.81162257]

# %%
y1_pred = lm.predict(X1)
y3_pred = lm1.predict(X3)
y5_pred = lm2.predict(X5)

# %%
fig, ax = plt.subplots()
plt.plot(X1, y1_pred, color='blue', linewidth=3)
plt.scatter(X1, y, color='black')
ax.set_xlabel('Value Over Replacement Player')
ax.set_ylabel('Win Shares')
# Out:
# Text(0, 0.5, 'Win Shares')

# %%
fig, ax = plt.subplots()
plt.plot(X3, y3_pred, color='green', linewidth=3)
plt.scatter(X3, y, color='black')
ax.set_xlabel('Box Plus/Minus Score')
ax.set_ylabel('Win Shares')
# Out:
# Text(0, 0.5, 'Win Shares')

# %%
fig, ax = plt.subplots()
plt.plot(X5, y5_pred, color='red', linewidth=3)
plt.scatter(X4, y, color='black')
ax.set_xlabel('Player Efficiency Rating')
ax.set_ylabel('Win Shares')
# Out:
# Text(0, 0.5, 'Win Shares')

# %%
fig, ax = plt.subplots()
plt.plot(X1, y1_pred, color='blue', linewidth=3)
plt.plot(X3, y3_pred, color='green', linewidth=3)
plt.plot(X5, y5_pred, color='red', linewidth=3)
plt.gca().legend(('VORP','BPM','PER'))
ax.set_ylabel('Win Shares')
ax.set_xlabel('Wholistic Statistic')
# Out:
# Text(0.5, 0, 'Wholistic Statistic')

# %%
# Out:
# Text(17.200000000000003, 0.5, 'Win Shares')

# %%
def TRB_categories(TRB):
    
    if TRB < 8:
        return 1
    else:
        return 2
data['TRB_categories'] = data['TRB%'].apply(TRB_categories)

sns.lmplot(x='TRB%', y='WS', hue='TRB_categories', data=data)
plt.xlabel('Total Rebounding Percentage')
plt.ylabel('Win Shares')
# Out:
# Text(31.334218749999998, 0.5, 'Win Shares')

# %%
def AST_categories(AST):
    
    if AST < 12:
        return 1
    else:
        return 2
data['AST_categories'] = data['AST%'].apply(AST_categories)

sns.lmplot(x='AST%', y='WS', hue='AST_categories', data=data)
plt.xlabel('Assist Percentage')
plt.ylabel('Win Shares')
# Out:
# Text(33.51607638888889, 0.5, 'Win Shares')

# %%
def BLK_categories(BLK):
    
    if BLK < 2:
        return 1
    else:
        return 2
data['BLK_categories'] = data['BLK%'].apply(BLK_categories)

sns.lmplot(x='BLK%', y='WS', hue='BLK_categories', data=data)
plt.xlabel('Block Percentage')
plt.ylabel('Win Shares')
# Out:
# Text(31.2259375, 0.5, 'Win Shares')

# %%
def TOV_categories(TOV):
    
    if TOV < 15:
        return 1
    else:
        return 2
data['TOV_categories'] = data['TOV%'].apply(TOV_categories)

sns.lmplot(x='TOV%', y='WS', hue='TOV_categories', data=data)
plt.xlabel('Turnover Percentage')
plt.ylabel('Win Shares')
# Out:
# Text(33.41333333333333, 0.5, 'Win Shares')

# %%
def USG_categories(USG):
    
    if USG < 19:
        return 1
    else:
        return 2
data['USG_categories'] = data['USG%'].apply(USG_categories)

sns.lmplot(x='USG%', y='WS', hue='USG_categories', data=data)
plt.xlabel('Usage Percentage')
plt.ylabel('Win Shares')
# Out:
# Text(34.33661458333333, 0.5, 'Win Shares')
